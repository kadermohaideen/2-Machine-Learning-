# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent = dataset[['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes']]

# %%
independent
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dependent=dataset[["charges"]]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(independent,dependent,test_size=1/3,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR

param_grid = {
    'kernel': ['rbf', 'poly', 'sigmoid', 'linear'],
    'C': [10, 100, 1000, 2000, 3000],
    'gamma': ['auto', 'scale']
}

grid = GridSearchCV(
    SVR(),
    param_grid,
    refit=True,
    verbose=3,
    n_jobs=-1
)

# Fitting the model for Grid Search
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# C:\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [10, 100, 1000, 2000, 3000],
#                          'gamma': ['auto', 'scale'],
#                          'kernel': ['rbf', 'poly', 'sigmoid', 'linear']},
#              verbose=3)

# %%
# print best parameter after tuning
# print(grid.best_params_)

re = grid.cv_results_

print("The R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'C': 3000, 'gamma': 'auto', 'kernel': 'linear'}:

# %%
table = pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0        0.087183      0.003326         0.032446        0.001757       10
# 1        0.062848      0.006684         0.011005        0.001284       10
# 2        0.078336      0.006629         0.013616        0.001110       10
# 3        0.063020      0.005167         0.011839        0.003087       10
# 4        0.083610      0.012459         0.033420        0.001819       10
# 5        0.063564      0.005770         0.011530        0.001043       10
# 6        0.072481      0.008040         0.015261        0.001320       10
# 7        0.057843      0.004213         0.011351        0.001786       10
# 8        0.071848      0.003588         0.034411        0.000560      100
# 9        0.062269      0.004791         0.012998        0.001520      100
# 10       0.077804      0.004904         0.014683        0.001744      100
# 11       4.692537      0.623594         0.004964        0.000439      100
# 12       0.072343      0.004011         0.038073        0.001473      100
# 13       0.073239      0.007087         0.014615        0.001475      100
# 14       0.093269      0.003900         0.016438        0.002553      100
# 15       5.060567      0.369717         0.004791        0.000985      100
# 16       0.100180      0.004908         0.039343        0.002457     1000
# 17       0.142783      0.032566         0.012391        0.001080     1000
# 18       0.081953      0.005594         0.016174        0.001194     1000
# 19       5.110160      0.816470         0.003415        0.000498     1000
# 20       0.104352      0.009455         0.040037        0.002121     1000
# 21       0.135767      0.023883         0.012233        0.000997     1000
# 22       0.074886      0.004545         0.014275        0.001160     1000
# 23       5.117960      1.095816         0.003887        0.000819     1000
# 24       0.144853      0.018695         0.042658        0.001839     2000
# 25       0.279800      0.056403         0.013931        0.000839     2000
# 26       0.093294      0.004804         0.017580        0.001035     2000
# 27       4.765937      1.981552         0.002855        0.000084     2000
# 28       0.181962      0.023503         0.057330        0.010742     2000
# 29       0.332514      0.082682         0.020413        0.003108     2000
# 30       0.127799      0.003824         0.025424        0.002207     2000
# 31       4.582561      1.454855         0.003866        0.001132     2000
# 32       0.229107      0.035151         0.048183        0.006613     3000
# 33       0.673002      0.282546         0.012666        0.001150     3000
# 34       0.091430      0.007073         0.017885        0.001679     3000
# 35       4.650103      1.252714         0.003573        0.000600     3000
# 36       0.191108      0.016174         0.044370        0.004977     3000
# 37       0.658761      0.237194         0.013488        0.000468     3000
# 38       0.099928      0.005330         0.017745        0.001633     3000
# 39       3.981255      0.706121         0.002313        0.000569     3000
#
#    param_gamma param_kernel  \
# 0         auto          rbf
# 1         auto         poly
# 2         auto      sigmoid
# 3         auto       linear
# 4        scale          rbf
# 5        scale         poly
# 6        scale      sigmoid
# 7        scale       linear
# 8         auto          rbf
# 9         auto         poly
# 10        auto      sigmoid
# 11        auto       linear
# 12       scale          rbf
# 13       scale         poly
# 14       scale      sigmoid
# 15       scale       linear
# 16        auto          rbf
# 17        auto         poly
# 18        auto      sigmoid
# 19        auto       linear
# 20       scale          rbf
# 21       scale         poly
# 22       scale      sigmoid
# 23       scale       linear
# 24        auto          rbf
# 25        auto         poly
# 26        auto      sigmoid
# 27        auto       linear
# 28       scale          rbf
# 29       scale         poly
# 30       scale      sigmoid
# 31       scale       linear
# 32        auto          rbf
# 33        auto         poly
# 34        auto      sigmoid
# 35        auto       linear
# 36       scale          rbf
# 37       scale         poly
# 38       scale      sigmoid
# 39       scale       linear
#
#                                                params  split0_test_score  \
# 0         {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}           0.019706
# 1        {'C': 10, 'gamma': 'auto', 'kernel': 'poly'}           0.229547
# 2     {'C': 10, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.136037
# 3      {'C': 10, 'gamma': 'auto', 'kernel': 'linear'}           0.804737
# 4        {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}           0.020393
# 5       {'C': 10, 'gamma': 'scale', 'kernel': 'poly'}           0.215035
# 6    {'C': 10, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.133719
# 7     {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}           0.804737
# 8        {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'}           0.461495
# 9       {'C': 100, 'gamma': 'auto', 'kernel': 'poly'}           0.828424
# 10   {'C': 100, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.793563
# 11    {'C': 100, 'gamma': 'auto', 'kernel': 'linear'}           1.000000
# 12      {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}           0.465543
# 13     {'C': 100, 'gamma': 'scale', 'kernel': 'poly'}           0.819463
# 14  {'C': 100, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.794175
# 15   {'C': 100, 'gamma': 'scale', 'kernel': 'linear'}           1.000000
# 16      {'C': 1000, 'gamma': 'auto', 'kernel': 'rbf'}           0.971894
# 17     {'C': 1000, 'gamma': 'auto', 'kernel': 'poly'}           0.917105
# 18  {'C': 1000, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.340892
# 19   {'C': 1000, 'gamma': 'auto', 'kernel': 'linear'}           1.000000
# 20     {'C': 1000, 'gamma': 'scale', 'kernel': 'rbf'}           0.972879
# 21    {'C': 1000, 'gamma': 'scale', 'kernel': 'poly'}           0.915140
# 22  {'C': 1000, 'gamma': 'scale', 'kernel': 'sigmo...           0.363995
# 23  {'C': 1000, 'gamma': 'scale', 'kernel': 'linear'}           1.000000
# 24      {'C': 2000, 'gamma': 'auto', 'kernel': 'rbf'}           0.990202
# 25     {'C': 2000, 'gamma': 'auto', 'kernel': 'poly'}           0.942301
# 26  {'C': 2000, 'gamma': 'auto', 'kernel': 'sigmoid'}          -1.192419
# 27   {'C': 2000, 'gamma': 'auto', 'kernel': 'linear'}           1.000000
# 28     {'C': 2000, 'gamma': 'scale', 'kernel': 'rbf'}           0.990437
# 29    {'C': 2000, 'gamma': 'scale', 'kernel': 'poly'}           0
# 25           0.941338         0.951632    8.597869e-03               16
# 26          -0.621458        -1.280678    4.579866e-01               38
# 27           1.000000         1.000000    4.187339e-12                3
# 28           0.919115         0.959118    2.338455e-02               14
# 29           0.943511         0.951712    8.945723e-03               15
# 30          -0.672003        -1.251631    4.163824e-01               37
# 31           1.000000         1.000000    4.187339e-12                3
# 32           0.932307         0.969993    2.075758e-02                9
# 33           0.959826         0.966116    5.956593e-03               11
# 34          -2.349648        -3.764270    9.067692e-01               40
# 35           1.000000         1.000000    2.956048e-12                1
# 36           0.931474         0.969802    2.108453e-02               10
# 37           0.961233         0.965979    6.610592e-03               12
# 38          -2.433635        -3.720649    8.768692e-01               39
# 39           1.000000         1.000000    2.956048e-12                1

# %%
age_input = float(input("Age:"))
bmi_input = float(input("BMI:"))
children_input = float(input("children:"))
sex_male_input = int(input("Sex Male 0 or 1:"))
smoker_yes_input = int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 32
# BMI: 42
# children: 2
# Sex Male 0 or 1: 0
# Smoker Yes 0 or 1: 1

# %%
Future_Prediction = grid.predict([[age_input, bmi_input, children_input, sex_male_input, smoker_yes_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 Future_Prediction = grid.predict([[age_input, bmi_input, children_input, sex_male_input, smoker_yes_input]]);
#       2 print("Future_Prediction={}".format(Future_Prediction))
#
# File C:\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:598, in BaseSearchCV.predict(self, X)
#     580 """Call predict on the estimator with the best found parameters.
#     581
#     582 Only available if ``refit=True`` and the underlying estimator supports
#    (...)    595     the best found parameters.
#     596 """
#     597 check_is_fitted(self)
# --> 598 return self.best_estimator_.predict(X)
#
# File C:\anaconda3\Lib\site-packages\sklearn\svm\_base.py:436, in BaseLibSVM.predict(self, X)
#     420 def predict(self, X):
#     421     """Perform regression on samples in X.
#     422
#     423     For an one-class model, +1 (inlier) or -1 (outlier) is returned.
#    (...)    434         The predicted values.
#     435     """
# --> 436     X = self._validate_for_predict(X)
#     437     predict = self._sparse_predict if self._sparse else self._dense_predict
#     438     return predict(X)
#
# File C:\anaconda3\Lib\site-packages\sklearn\svm\_base.py:614, in BaseLibSVM._validate_for_predict(self, X)
#     611 check_is_fitted(self)
#     613 if not callable(self.kernel):
# --> 614     X = validate_data(
#     615         self,
#     616         X,
#     617         accept_sparse="csr",
#     618         dtype=np.float64,
#     619         order="C",
#     620         accept_large_sparse=False,
#     621         reset=False,
#     622     )
#     624 if self._sparse and not sp.issparse(X):
#     625     X = sp.csr_matrix(X)
#
# File C:\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2975, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2972     out = X, y
#    2974 if not no_val_X and check_params.get("ensure_2d", True):
# -> 2975     _check_n_features(_estimator, X, reset=reset)
#    2977 return out
#
# File C:\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2839, in _check_n_features(estimator, X, reset)
#    2836     return
#    2838 if n_features != estimator.n_features_in_:
# -> 2839     raise ValueError(
#    2840         f"X has {n_features} features, but {estimator.__class__.__name__} "
#    2841         f"is expecting {estimator.n_features_in_} features as input."
#    2842     )
#
# ValueError: X has 5 features, but SVR is expecting 6 features as input.
